# %% [markdown]
# 1. Input/Output
# 2. Variables
# 3. Datatypes
# 4. Operators

# %% [markdown]
# #### How machine understands code?
# Code(Python) -> Translate (Compiler, Interpreter) -> Machine (0,1)

# %%
# First Program
print("Hello world!")
# Out:
# Hello world!

# %%
print("Suman", "Neupane")
print(23, 4)
print(23+4)
# Out:
# Suman Neupane
# 23 4
# 27

# %% [markdown]
# Variables

# %%
name = "John"
age = 23
price = 3.45

print(name, age, price)
# Out:
# John 23 3.45

# %%
a = 5
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b) # quotient value
print(a % b) # remainder value
print(a ** b)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2
# 125

# %%
a = 10
b = 2
print(a == b)
print(a != b)
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
a = 5
b = 3
c = a + b
print(c)

d = b
d += a
print(d)

e = b
e -= a
print(e)

f = b
f *= a
print(f)

g = b
g /= a
print(g)

h = b
h %= a
print(h)

i = b
i **= a
print(i)
# Out:
# 8
# 8
# -2
# 15
# 0.6
# 3
# 243

# %%
a = 5
b = 3

print(not False)
print(not (a > b))

print(False and True)
print(True or False)
# Out:
# True
# False
# False
# True

# %%
s = input("Inter any number:")
print(s)
# Out:
# suman

# %%
r = int(input("Inter First number:"))
s = int(input("Inter Second number:"))

print(r + s)
# Out:
# 3

# %%
l = int(input("Enter length of square:"))
print(l * l)
# Out:
# 4

# %%
w1 = float(input("Enter first floating number:"))
w2 = float(input("Enter second floating number:"))

print(w1, w2)
print((w1 + w2) / 2)
# Out:
# 2.0 3.0
# 2.5

# %%
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

print(a >= b)
# Out:
# True
