# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid = pd.read_csv('4. Covid_19_data.csv')

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
sns.heatmap(data= covid.isnull())
# Out:
# <Axes: >

# %%
covid.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid.groupby('Region')[['Confirmed', 'Deaths', 'Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
mask = covid['Confirmed'] > 10
covid[mask]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [301 rows x 6 columns]

# %%
covid.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
covid.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(10)
# Out:
# Region
# Laos                0
# Mongolia            0
# Mozambique          0
# Cambodia            0
# Fiji                0
# Namibia             0
# Nepal               0
# Madagascar          0
# Macau               0
# Papua New Guinea    0
# Name: Deaths, dtype: int64

# %%
maskRegion = covid['Region'] == 'India'
maskDate = covid['Date'] <= '4/29/2020'
covid[maskRegion & maskDate].value_counts()
# Out:
# Date       State                  Region  Confirmed  Deaths  Recovered
# 4/29/2020  Alabama                India   6912       256     0            1
#            Oregon                 India   2446       101     0            1
#            Northern Territory     India   28         0       25           1
#            Northwest Territories  India   5          0       0            1
#            Nova Scotia            India   935        28      0            1
#                                                                          ..
#            Guangxi                India   254        2       252          1
#            Guangdong              India   1588       8       1557         1
#            Guam                   India   141        5       0            1
#            Guadeloupe             India   149        12      82           1
#            Zhejiang               India   1268       1       1263         1
# Name: count, Length: 140, dtype: int64

# %%
covid.sort_values('Confirmed', ascending=False)
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 265  4/29/2020                      New York  India     299691   23477
# 153  4/29/2020                           NaN  India     236899   24275
# 80   4/29/2020                           NaN  India     203591   27682
# 168  4/29/2020                           NaN  India     165221   26097
# 57   4/29/2020                           NaN  India     165093   24087
# ..         ...                           ...    ...        ...     ...
# 305  4/29/2020                         Tibet  India          1       0
# 289  4/29/2020     Saint Pierre and Miquelon  India          1       0
# 285  4/29/2020                     Recovered  India          0       0
# 284  4/29/2020                     Recovered  India          0       0
# 203  4/29/2020  Diamond Princess cruise ship  India          0       1
#
#      Recovered
# 265          0
# 153     132929
# 80       71252
# 168          0
# 57       48228
# ..         ...
# ...
