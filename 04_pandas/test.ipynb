# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('ipl_data.csv')

# %%
data.head(3)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
# 1  normal           0    Chennai Super Kings           33               0
# 2  normal           0       Delhi Daredevils            0               9
#
#   player_of_match                                       venue    umpire1  \
# ...

# %%
data[['city', 'team1', 'toss_winner']]
# Out:
#            city                  team1                  toss_winner
# 0     Bangalore  Kolkata Knight Riders  Royal Challengers Bangalore
# 1    Chandigarh    Chennai Super Kings          Chennai Super Kings
# 2         Delhi       Rajasthan Royals             Rajasthan Royals
# 3        Mumbai         Mumbai Indians               Mumbai Indians
# 4       Kolkata        Deccan Chargers              Deccan Chargers
# ..          ...                    ...                          ...
# 572      Raipur       Delhi Daredevils  Royal Challengers Bangalore
# 573   Bangalore          Gujarat Lions  Royal Challengers Bangalore
# 574       Delhi    Sunrisers Hyderabad        Kolkata Knight Riders
# 575       Delhi          Gujarat Lions          Sunrisers Hyderabad
# 576   Bangalore    Sunrisers Hyderabad          Sunrisers Hyderabad
#
# [577 rows x 3 columns]

# %%
data.iloc[[0, 10, 20]]
# Out:
#     id  season       city        date                        team1  \
# 0    1    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 10  11    2008  Bangalore  2008-04-26  Royal Challengers Bangalore
# 20  21    2008  Hyderabad  2008-05-25              Deccan Chargers
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 10             Rajasthan Royals             Rajasthan Royals         field
# 20  Royal Challengers Bangalore              Deccan Chargers           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# 0   normal           0        Kolkata Knight Riders          140
# 10  normal           0             Rajasthan Royals            0
# 20  normal           0  Royal Challengers Bangalore            0
#
#     win_by_wickets player_of_match                                      venue  \
# ...

# %%
maskCity = data['city'] == 'Hyderabad'
maskWinner =  data['winner'] == 'Kolkata Knight Riders'
mask = maskCity & maskWinner

# %%
data[mask]
# Out:
#       id  season       city        date                  team1  \
# 32    33    2008  Hyderabad  2008-05-11  Kolkata Knight Riders
# 215  216    2011  Hyderabad  2011-05-03  Kolkata Knight Riders
# 440  441    2014  Hyderabad  2014-05-18    Sunrisers Hyderabad
# 524  525    2016  Hyderabad  2016-04-16    Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# 32         Deccan Chargers  Kolkata Knight Riders           bat  normal
# 215        Deccan Chargers        Deccan Chargers         field  normal
# 440  Kolkata Knight Riders    Sunrisers Hyderabad           bat  normal
# 524  Kolkata Knight Riders    Sunrisers Hyderabad           bat  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 32            0  Kolkata Knight Riders           23               0
# 215           0  Kolkata Knight Riders           20               0
# 440           0  Kolkata Knight Riders            0               7
# ...

# %%
data['toss_decision'].value_counts()
# Out:
# toss_decision
# field    315
# bat      262
# Name: count, dtype: int64

# %%
import  matplotlib.pyplot as plt
data['toss_decision'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='toss_decision'>

# %%
data['winner'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data.plot(kind='scatter', x="win_by_runs", y="toss_winner", subplots=True)
# Out:
# array([<Axes: xlabel='win_by_runs', ylabel='toss_winner'>], dtype=object)

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, 4, 5],
    "B": [5, 4, 3, 2, 1]
})

df.plot(subplots=True, layout=(2, 2), figsize=(10, 10))
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

df["A"].plot(ax=axes[0], kind="line")
df["B"].plot(ax=axes[1], kind="bar")

plt.show()

# %%
df.plot(
    subplots=True,
    figsize=(8, 6),
    layout=(2, 2)
)

plt.show()

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, 4, 5],
    "B": [5, 4, 3, 2, 1],
    "C": [5, 4, 3, 2, 1],
    "D": [5, 4, 3, 2, 1],
})

fig, axes = plt.subplots(2, 2, figsize=(10, 4))

df["A"].plot(ax=axes[0,0], kind="line")
df["B"].plot(ax=axes[0,1], kind="bar")
df["C"].plot(ax=axes[1,0], kind="line")
df["D"].plot(ax=axes[1,1], kind="bar")

plt.show()

# %%
a = data.groupby(["city", "team1"])["toss_decision"]

# %%
a.count().head().plot(kind="bar")
# Out:
# <Axes: xlabel='city,team1'>

# %%
df.corr()
# Out:
#      A    B    C    D
# A  1.0 -1.0 -1.0 -1.0
# B -1.0  1.0  1.0  1.0
# C -1.0  1.0  1.0  1.0
# D -1.0  1.0  1.0  1.0

# %%
df = df.rename({'A': 'AA', 'D': 'DD'}, axis='columns')

# %%
df.corr()
# Out:
#      AA    B    C   DD
# AA  1.0 -1.0 -1.0 -1.0
# B  -1.0  1.0  1.0  1.0
# C  -1.0  1.0  1.0  1.0
# DD -1.0  1.0  1.0  1.0

# %%
data.set_index(["id"], inplace=True)
data.head()
# Out:
#     season        city        date                  team1  \
# id
# 1     2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 2     2008  Chandigarh  2008-04-19    Chennai Super Kings
# 3     2008       Delhi  2008-04-19       Rajasthan Royals
# 4     2008      Mumbai  2008-04-20         Mumbai Indians
# 5     2008     Kolkata  2008-04-20        Deccan Chargers
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2               Kings XI Punjab          Chennai Super Kings           bat
# 3              Delhi Daredevils             Rajasthan Royals           bat
# 4   Royal Challengers Bangalore               Mumbai Indians           bat
# 5         Kolkata Knight Riders              Deccan Chargers           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# 1   normal           0        Kolkata Knight Riders          140
# ...
